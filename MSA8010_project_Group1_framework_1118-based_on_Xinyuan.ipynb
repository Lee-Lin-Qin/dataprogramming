# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Task-Details" data-toc-modified-id="Task-Details-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Task Details</a></span></li><li><span><a href="#Import-the-core-libraries" data-toc-modified-id="Import-the-core-libraries-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Import the core libraries</a></span></li><li><span><a href="#Get-the-data,-explore-the-data-structure" data-toc-modified-id="Get-the-data,-explore-the-data-structure-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Get the data, explore the data structure</a></span><ul class="toc-item"><li><span><a href="#Import-the-dataset" data-toc-modified-id="Import-the-dataset-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Import the dataset</a></span></li><li><span><a href="#Check-for-missing-values" data-toc-modified-id="Check-for-missing-values-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Check for missing values</a></span></li><li><span><a href="#Numerical-factors-and-categorical-factors" data-toc-modified-id="Numerical-factors-and-categorical-factors-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Numerical factors and categorical factors</a></span><ul class="toc-item"><li><span><a href="#Target-(Response)-in-train-dataset" data-toc-modified-id="Target-(Response)-in-train-dataset-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Target (Response) in train dataset</a></span></li><li><span><a href="#Correlation-analysis" data-toc-modified-id="Correlation-analysis-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Correlation analysis</a></span></li></ul></li></ul></li><li><span><a href="#EDA-(Exploratory-Data-Analysis)" data-toc-modified-id="EDA-(Exploratory-Data-Analysis)-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>EDA (Exploratory Data Analysis)</a></span></li><li><span><a href="#Sampling" data-toc-modified-id="Sampling-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Sampling</a></span><ul class="toc-item"><li><span><a href="#Pure-random-sampling" data-toc-modified-id="Pure-random-sampling-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Pure random sampling</a></span></li><li><span><a href="#Stratified-sampling" data-toc-modified-id="Stratified-sampling-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Stratified sampling</a></span></li><li><span><a href="#Over-sampling" data-toc-modified-id="Over-sampling-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Over-sampling</a></span></li><li><span><a href="#Under-sampling" data-toc-modified-id="Under-sampling-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Under-sampling</a></span></li><li><span><a href="#Summary-of-sampling" data-toc-modified-id="Summary-of-sampling-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Summary of sampling</a></span></li></ul></li><li><span><a href="#Models" data-toc-modified-id="Models-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Models</a></span><ul class="toc-item"><li><span><a href="#Models-based-on-original-data-set" data-toc-modified-id="Models-based-on-original-data-set-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Models based on original data set</a></span><ul class="toc-item"><li><span><a href="#Logistic-regression" data-toc-modified-id="Logistic-regression-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Logistic regression</a></span></li><li><span><a href="#Modified-logistic-regression" data-toc-modified-id="Modified-logistic-regression-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Modified logistic regression</a></span></li><li><span><a href="#Support-vector-machine-(SVM)" data-toc-modified-id="Support-vector-machine-(SVM)-6.1.3"><span class="toc-item-num">6.1.3&nbsp;&nbsp;</span>Support vector machine (SVM)</a></span></li><li><span><a href="#Decision-tree" data-toc-modified-id="Decision-tree-6.1.4"><span class="toc-item-num">6.1.4&nbsp;&nbsp;</span>Decision tree</a></span></li><li><span><a href="#Random-forest" data-toc-modified-id="Random-forest-6.1.5"><span class="toc-item-num">6.1.5&nbsp;&nbsp;</span>Random forest</a></span></li></ul></li><li><span><a href="#Models-based-on-adjusted-data-set" data-toc-modified-id="Models-based-on-adjusted-data-set-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Models based on adjusted data set</a></span><ul class="toc-item"><li><span><a href="#logistic-regression" data-toc-modified-id="logistic-regression-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>logistic regression</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
#  <h1>Health Insurance Cross Sell Prediction -- Group_1<span class="tocSkip"></span></h1>
# Cross-sell PredictionPredict Health Insurance Owners' who will be interested in Vehicle Insurance
#
# The project is captured from Kaggle:
# https://www.kaggle.com/anmolkumar/health-insurance-cross-sell-prediction/tasks?taskId=2055

# %% [markdown]
# # Task Details
# Your client is an Insurance company that has provided Health Insurance to its customers now they need your help in building a model to predict whether the policyholders (customers) from past year will also be interested in Vehicle Insurance provided by the company.
#
# For example, you may pay a premium of Rs. 5000 each year for a health insurance cover of Rs. 200,000/- so that if, God forbid, you fall ill and need to be hospitalised in that year, the insurance provider company will bear the cost of hospitalisation etc. for upto Rs. 200,000. Now if you are wondering how can company bear such high hospitalisation cost when it charges a premium of only Rs. 5000/-, that is where the concept of probabilities comes in picture. For example, like you, there may be 100 customers who would be paying a premium of Rs. 5000 every year, but only a few of them (say 2-3) would get hospitalised that year and not everyone. This way everyone shares the risk of everyone else.
#
# Just like medical insurance, there is vehicle insurance where every year customer needs to pay a premium of certain amount to insurance provider company so that in case of unfortunate accident by the vehicle, the insurance provider company will provide a compensation (called ‘sum assured’) to the customer.
#
# Building a model to predict whether a customer would be interested in Vehicle Insurance is extremely helpful for the company because it can then accordingly plan its communication strategy to reach out to those customers and optimise its business model and revenue.
#
# Now, in order to predict, whether the customer would be interested in Vehicle insurance, you have information about demographics (gender, age, region code type), Vehicles (Vehicle Age, Damage), Policy (Premium, sourcing channel) etc.

# %% [markdown]
# # Import the core libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.options.display.max_rows=None
pd.options.display.max_columns=None

# %% [markdown]
# # Get the data, explore the data structure

# %% [markdown]
# ## Import the dataset

# %%
train = pd.read_csv('train.csv', sep=',', header=0) # training data
test = pd.read_csv('test.csv', sep=',', header=0) # test data

# %%
train.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   1    Male   44                1         28.0                   0
# 1   2    Male   76                1          3.0                   0
# 2   3    Male   47                1         28.0                   0
# 3   4    Male   21                1         11.0                   1
# 4   5  Female   29                1         41.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0   > 2 Years            Yes         40454.0                  26.0      217
# 1    1-2 Year             No         33536.0                  26.0      183
# 2   > 2 Years            Yes         38294.0                  26.0       27
# 3    < 1 Year             No         28619.0                 152.0      203
# 4    < 1 Year             No         27496.0                 152.0       39
#
#    Response
# 0         1
# 1         0
# 2         1
# 3         0
# 4         0

# %%
test.head()
# Out:
#        id Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0  381110   Male   25                1         11.0                   1
# 1  381111   Male   40                1         28.0                   0
# 2  381112   Male   47                1         28.0                   0
# 3  381113   Male   24                1         27.0                   1
# 4  381114   Male   27                1         28.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage
# 0    < 1 Year             No         35786.0                 152.0       53
# 1    1-2 Year            Yes         33762.0                   7.0      111
# 2    1-2 Year            Yes         40050.0                 124.0      199
# 3    < 1 Year            Yes         37356.0                 152.0      187
# 4    < 1 Year             No         59097.0                 152.0      297

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381109 entries, 0 to 381108
# Data columns (total 12 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    381109 non-null  int64
#  1   Gender                381109 non-null  object
#  2   Age                   381109 non-null  int64
#  3   Driving_License       381109 non-null  int64
#  4   Region_Code           381109 non-null  float64
#  5   Previously_Insured    381109 non-null  int64
#  6   Vehicle_Age           381109 non-null  object
#  7   Vehicle_Damage        381109 non-null  object
#  8   Annual_Premium        381109 non-null  float64
#  9   Policy_Sales_Channel  381109 non-null  float64
#  10  Vintage               381109 non-null  int64
#  11  Response              381109 non-null  int64
# dtypes: float64(3), int64(6), object(3)
# memory usage: 30.5+ MB

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127037 entries, 0 to 127036
# Data columns (total 11 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   id                    127037 non-null  int64
#  1   Gender                127037 non-null  object
#  2   Age                   127037 non-null  int64
#  3   Driving_License       127037 non-null  int64
#  4   Region_Code           127037 non-null  float64
#  5   Previously_Insured    127037 non-null  int64
#  6   Vehicle_Age           127037 non-null  object
#  7   Vehicle_Damage        127037 non-null  object
#  8   Annual_Premium        127037 non-null  float64
#  9   Policy_Sales_Channel  127037 non-null  float64
#  10  Vintage               127037 non-null  int64
# dtypes: float64(3), int64(5), object(3)
# memory usage: 9.2+ MB

# %%
train.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  381109.000000  381109.000000    381109.000000  381109.000000
# mean   190555.000000      38.822584         0.997869      26.388807
# std    110016.836208      15.511611         0.046110      13.229888
# min         1.000000      20.000000         0.000000       0.000000
# 25%     95278.000000      25.000000         1.000000      15.000000
# 50%    190555.000000      36.000000         1.000000      28.000000
# 75%    285832.000000      49.000000         1.000000      35.000000
# max    381109.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel  \
# count       381109.000000   381109.000000         381109.000000
# mean             0.458210    30564.389581            112.034295
# std              0.498251    17213.155057             54.203995
# min              0.000000     2630.000000              1.000000
# ...

# %%
test.describe()
# Out:
#                   id            Age  Driving_License    Region_Code  \
# count  127037.000000  127037.000000    127037.000000  127037.000000
# mean   444628.000000      38.765903         0.998134      26.459866
# std     36672.567411      15.465814         0.043152      13.209916
# min    381110.000000      20.000000         0.000000       0.000000
# 25%    412869.000000      25.000000         1.000000      15.000000
# 50%    444628.000000      36.000000         1.000000      28.000000
# 75%    476387.000000      49.000000         1.000000      35.000000
# max    508146.000000      85.000000         1.000000      52.000000
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel        Vintage
# count       127037.000000   127037.000000         127037.000000  127037.000000
# mean             0.460039    30524.643576            111.800468     154.318301
# std              0.498403    16945.297103             54.371765      83.661588
# ...

# %%
train.hist(bins = 50, figsize = (20, 10))
plt.show()

# %%
test.hist(bins = 50, figsize = (20, 10))
plt.show()

# %%
train.Region_Code.unique()
# Out:
# array([28.,  3., 11., 41., 33.,  6., 35., 50., 15., 45.,  8., 36., 30.,
#        26., 16., 47., 48., 19., 39., 23., 37.,  5., 17.,  2.,  7., 29.,
#        46., 27., 25., 13., 18., 20., 49., 22., 44.,  0.,  9., 31., 12.,
#        34., 21., 10., 14., 38., 24., 40., 43., 32.,  4., 51., 42.,  1.,
#        52.])

# %%
train.Vehicle_Damage.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %% [markdown]
# ## Check for missing values

# %%
train.isnull().sum() # check for missing values in train dataset
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# Response                0
# dtype: int64

# %%
test.isnull().sum() # check for missing values in test dataset
# Out:
# id                      0
# Gender                  0
# Age                     0
# Driving_License         0
# Region_Code             0
# Previously_Insured      0
# Vehicle_Age             0
# Vehicle_Damage          0
# Annual_Premium          0
# Policy_Sales_Channel    0
# Vintage                 0
# dtype: int64

# %% [markdown]
# ## Numerical factors and categorical factors

# %%
nums =['Age', 'Region_Code', 'Annual_Premium', 'Vintage'] # numerical factors
cats=['Gender', 'Driving_License', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Response'] # categorical factors

# %% [markdown]
# ### Target (Response) in train dataset

# %%
y_train = train['Response'] # label in the train data: Response
sns.countplot(x = y_train) 

from collections import Counter
counts_y_train = Counter(y_train)
counts_y_train
# Out:
# Counter({1: 46710, 0: 334399})

# %%
imbalance_ratio = counts_y_train[0]/counts_y_train[1]
imbalance_ratio
# Out:
# 7.15904517233997

# %% [markdown]
# *We notice that the train dataset is highly imbalanced*

# %% [markdown]
# ### Correlation analysis

# %%
# Correlation matrix
train.corr()
# Out:
#                             id       Age  Driving_License  Region_Code  \
# id                    1.000000  0.001561        -0.000564    -0.000572
# Age                   0.001561  1.000000        -0.079782     0.042574
# Driving_License      -0.000564 -0.079782         1.000000    -0.001081
# Region_Code          -0.000572  0.042574        -0.001081     1.000000
# Previously_Insured    0.002457 -0.254682         0.014969    -0.024659
# Annual_Premium        0.003027  0.067507        -0.011906    -0.010588
# Policy_Sales_Channel -0.002837 -0.577826         0.043731    -0.042420
# Vintage              -0.000630 -0.001264        -0.000848    -0.002750
# Response             -0.001368  0.111147         0.010155     0.010570
#
#                       Previously_Insured  Annual_Premium  \
# id                              0.002457        0.003027
# Age                            -0.254682        0.067507
# Driving_License                 0.014969       -0.011906
# ...

# %%
# %%time 
sns.pairplot(train)
plt.show()
# Out:
# Wall time: 1min 22s

# %% [markdown]
# # EDA (Exploratory Data Analysis)

# %% [markdown]
# # Sampling

# %% [markdown]
# ## Pure random sampling

# %% [markdown]
# ## Stratified sampling

# %% [markdown]
# ## Over-sampling

# %% [markdown]
# ## Under-sampling

# %% [markdown]
# ##  Summary of sampling

# %% [markdown]
# # Models

# %% [markdown]
# ## Models based on original data set

# %% [markdown]
# ###  Logistic regression

# %% [markdown]
# **4.1.1. Fit a logistic regression model**

# %% [markdown]
# **4.1.2. Evaluate the model on the training data set**

# %% [markdown]
# **4.1.3. Evaluate the model on the test data set**

# %% [markdown]
# ### Modified logistic regression

# %% [markdown]
# **4.2.1. Fit a modified logistic regression model**

# %% [markdown]
# **4.2.2. Evaluate the model on the training data set**

# %% [markdown]
# **4.2.3. Evaluate the model on the test data set**

# %% [markdown]
# ###  Support vector machine (SVM)

# %% [markdown]
# **4.3.1. Fit an SVM model**

# %% [markdown]
# **4.3.2. Evaluate the model on the training data set**

# %% [markdown]
# **4.3.3. Evaluate the model on the test data set**

# %% [markdown]
# ###  Decision tree

# %% [markdown]
# **4.4.1. Fit a decision tree model**

# %% [markdown]
# **4.4.2. Evaluate the model on the training data set**

# %% [markdown]
# **4.4.3. Evaluate the model on the test data set**

# %% [markdown]
# ### Random forest

# %% [markdown]
# **4.5.1. Fit a random forest model**

# %% [markdown]
# **4.5.2. Evaluate the model on the training data set**

# %% [markdown]
# **4.5.3. Evaluate the model on the test data set**

# %% [markdown]
# ## Models based on adjusted data set

# %% [markdown]
# ### logistic regression
